# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.ticker as ticker
# %matplotlib inline
import astropy
from astropy.modeling import models, fitting
from astropy.table import Table
from astropy.io import fits
from astropy.coordinates import SkyCoord, Angle
from astropy.wcs import WCS
from regions import CircleSkyRegion, CirclePixelRegion
import astropy.constants as const
import astropy.units as u
from astropy.cosmology import FlatLambdaCDM
import pandas as pd
from scipy.integrate import simps
import aplpy
from uncertainties import ufloat

# %%
# read in data files
z2a = pd.read_csv('./resources/zprofile-2a.tsv', sep='\t', skiprows=6, header=None)
z2b = pd.read_csv('./resources/zprofile-2b.tsv', sep='\t', skiprows=6, header=None)
z2c = pd.read_csv('./resources/zprofile-2c.tsv', sep='\t', skiprows=6, header=None)

colnames = ['freq', 'intensity']
z2a.columns, z2a.name = colnames, '2a'
z2b.columns, z2b.name = colnames, '2b'
z2c.columns, z2c.name = colnames, '2c'

zprofs = [z2a, z2b, z2c]

# %%
# initialize 1d gaussian fit
g_init = models.Gaussian1D(amplitude=2e-4, mean=88.2, stddev=1.)
fit_g = fitting.LevMarLSQFitter()
g_fits = [None] * 3

# %%
fig = plt.figure(figsize=(15, 5), dpi=100)
for i, j in enumerate(zprofs):
    ax = fig.add_subplot(1, 3, i+1)
    
    ax.step(j.freq, j.intensity)
    ax.set_title(f'Gal. {j.name}')
    
    ax.set_ylabel('Intensity (Jy/beam)')   
    ax.set_xlabel('Observed frequency (GHz)', labelpad=10)
    
    ax.set_ylim(-0.00025, .00065)
    
    ax.axhline(0, linestyle=":", c='black', alpha=0.5)

plt.subplots_adjust(wspace=.4)
plt.tight_layout()
plt.autoscale()
plt.savefig('figs/initial_spectra.pdf', bbox_inches = "tight")

# %%
fig, ax = plt.subplots(3, figsize=(10, 15), dpi=100)
for i, j in enumerate(zprofs):
    g = fit_g(g_init, j.freq, j.intensity)
    g_fits[i] = g
    ax[i].step(j.freq, j.intensity, label='Data')
    ax[i].plot(j.freq, g(j.freq), label='Gaussian fit')
    ax[i].set_title(f'Gal. {j.name}')
    ax[i].legend()
    
plt.subplots_adjust(hspace=0.4)
ax[1].set_ylabel('Intensity (Jy/beam)')
ax[2].set_xlabel('Observed frequency (GHz)', labelpad=20);

plt.savefig('figs/gaussian_fit.pdf')

# %%
for g in g_fits:
    print(g.amplitude)
    print(g.mean)
    print(g.stddev)
    print(f'FWHM: {g.stddev * 2 * np.sqrt(2 * np.log(2))}')
    print('\n')
# Out:
# Parameter('amplitude', value=4.3242787586700213e-05)
# Parameter('mean', value=87.96442293348686)
# Parameter('stddev', value=0.3642692876320899, bounds=(1.1754943508222875e-38, None))
# FWHM: 0.8577886203051898
#
#
# Parameter('amplitude', value=0.0004665800163583173)
# Parameter('mean', value=88.1888718691281)
# Parameter('stddev', value=0.046952200186649654, bounds=(1.1754943508222875e-38, None))
# FWHM: 0.11056398215782849
#
#
# Parameter('amplitude', value=0.0006358347176616632)
# Parameter('mean', value=88.19636046157565)
# Parameter('stddev', value=0.027207947731166603, bounds=(1.1754943508222875e-38, None))
# FWHM: 0.06406982070150545

# %%
def z_from_freq(obs_freq, rest_freq):
    """ Given (arrays of) observed and rest frequencies, calculate redshift.
    """
    return (rest_freq / obs_freq) - 1

# %%
co_j32_freq = 345.8 # GHz
obs_freqs = np.array([ufloat(g.mean.value, g.stddev.value) for g in g_fits])
obs_freqs # GHz
# Out:
# array([87.96442293348686+/-0.3642692876320899,
#        88.1888718691281+/-0.046952200186649654,
#        88.19636046157565+/-0.027207947731166603], dtype=object)

# %%
redshifts = z_from_freq(obs_freqs, co_j32_freq)

# %%
@np.vectorize
def velocity_radio(obs_freq, rest_freq, z=0):
    """ Given (arrays of) observed and rest frequencies, calculate radio velocity in m/s.
    Optionally, shift the zero point of the velocity frame into the source by redshifting rest frequency. 
    """
    shifted_rest_freq = rest_freq / (z + 1)
    return (1 - obs_freq / shifted_rest_freq) * const.c.value

# %%
xlabs_bottom
# Out:
# [3328.576837577439,
#  2728.6302037887403,
#  2128.6835700000747,
#  1528.7369362115091,
#  928.7903024228101,
#  328.84366863421104,
#  -271.10296515452114,
#  -871.0495989430536,
#  -1470.9962327318524,
#  -2070.9428665203186,
#  -2670.8895003090506]

# %%
velocity_radio(obs_freqs[1], co_j32_freq, redshifts[1])
# Out:
# array(0.0+/-0, dtype=object)

# %%
fig = plt.figure(figsize=(10, 15), dpi=100)
# plt.locator_params(nbins=10, axis='x')

for i, j in enumerate(zprofs):
    ax = fig.add_subplot(3, 1, i+1)
    ax.set_xlim(j.freq.values[0], j.freq.values[-1])
    
    vel_r = velocity_radio(j.freq, co_j32_freq, redshifts[i])
    xlabs_bottom = [i.n-100 for i in vel_r[::6] / 1000] # convert to km/s, account for 1 unit shift
    ax.step(j.freq, j.intensity, label='Data')
    ax.plot(j.freq, g_fits[i](j.freq), label='Gaussian fit')
    ax.legend(title=f'Gal. {j.name}, z~{redshifts[i]:.3f}', loc='upper right')

    # create second axis for redshift
    ax2 = ax.twiny()
    
    ax2.set_xlim(xlabs_bottom[0], xlabs_bottom[-1])
    plt.xticks((np.arange(xlabs_bottom[-1], xlabs_bottom[0], 100)[::-1] / 100).astype(int) * 100)
    
    ax2.xaxis.set_major_locator(ticker.MultipleLocator(500))
    ax2.xaxis.set_major_formatter(ticker.FormatStrFormatter('%d'))

    # For the minor ticks, use no labels; default NullFormatter.
    ax2.xaxis.set_minor_locator(ticker.MultipleLocator(250))
    
    # move frequency axis+label to top, redshift axis+label to bottom
    ax.xaxis.tick_top()
    ax.xaxis.set_label_position('top')
    
    ax2.xaxis.tick_bottom()
    ax2.xaxis.set_label_position('bottom')
    

    # kinda ugly...
    
    # set top x label
    if i == 0: 
        ax.set_xlabel('Frequency (GHz)', labelpad=10)
    
    # set y label
    if i == 1: 
        ax.set_ylabel('Intensity (Jy/beam)')
        
    # set bottom x label
    if i == 2: 
        ax2.set_xlabel('Radio velocity (km/s)', labelpad=20)
    
    
plt.subplots_adjust(hspace=0.4)
plt.savefig('figs/velocity_axis_plot.pdf')

# %%
def RMS(signal):
    """ Return root-mean-square of a signal
    """
    return np.sqrt(np.mean(np.square(signal)))

# %%
z2b_ = z2b.copy()
z2c_ = z2c.copy()
z2b_ = np.delete(z2b_.intensity.values, [[32, 33, 34]])
z2c_ = np.delete(z2c_.intensity.values, [[33, 33, 34]])

# %%
[f'{RMS(i):.2E}' for i in [z2a.intensity, z2b_, z2c_]]
# Out:
# ['1.11E-04', '1.15E-04', '1.08E-04']

# %%
# fig, ax = plt.subplots(1, 3, figsize=(16, 4))


# ax[0].step(z2a.freq, z2a.intensity, label='Data')
# ax[0].set_title('Gal. 2a')
# ax[0].legend()

# ax[1].step(z2b.freq, z2b.intensity, label='Data')
# ax[1].step(z2b.freq, z2b_.intensity, label='RMS signal')
# ax[1].set_title('Gal. 2b')
# ax[1].legend()

# ax[2].step(z2c.freq, z2c.intensity, label='Data')
# ax[2].step(z2c.freq, z2c_.intensity, label='RMS signal')
# ax[2].set_title('Gal. 2c')
# ax[2].legend()

# %%
FWHM = [g.stddev * 2 * np.sqrt(2 * np.log(2)) for g in g_fits]
up_fwhm = np.mean((FWHM[1], FWHM[2]))
uplf2a = up_fwhm * 3 * RMS(z2a.intensity)
uplf2a
# Out:
# 2.9181253143838845e-05

# %%
s_co32_dvs = np.array([simps(y=g_fits[i](zprofs[i].freq), x=zprofs[i].freq) for i in np.arange(len(zprofs))]) * u.Jy * u.km / u.s
s_co32_dvs
# Out:
# <Quantity [3.86288022e-05, 5.49127274e-05, 4.36254186e-05] Jy km / s>

# %%
s_co32_dvs[0] = uplf2a * u.Jy * u.km / u.s
s_co32_dvs
# Out:
# <Quantity [2.91812531e-05, 5.49127274e-05, 4.36254186e-05] Jy km / s>

# %%
redshifts
# Out:
# array([2.931134752756488+/-0.016279213893725414,
#        2.9211296467559498+/-0.0020876292011706896,
#        2.920796710774183+/-0.0012095378019340106], dtype=object)

# %%
cosmo = FlatLambdaCDM(H0=70, Tcmb0=2.72548, Om0=0.3) # default Tcmb0=0 gives very similar results
lum_dists = cosmo.luminosity_distance([i.n for i in redshifts])
[f'{i:.2E}' for i in lum_dists.value]
# Out:
# ['2.47E+04', '2.46E+04', '2.46E+04']

# %%
def line_luminosity(fluxes, lum_dists, zs, freq_obs):
    """ See first eqn. on Carilli and Walter 2013 p. 9
    """
    return (const.c**2 / (2 * const.k_B) * fluxes * np.square(lum_dists) / (np.power(1+zs, 3) * np.square(freq_obs))).to(u.K * u.km * u.pc**2 / u.s)

# %%
lco32 = 3.25e7 * s_co32_dvs.value * np.square(lum_dists.value) / (np.power(1 + np.array([i for i in redshifts]), 3) * np.square(obs_freqs))
for i in lco32:
    print(i)
# Out:
# (1.233+/-0.005)e+06
# (2.3062+/-0.0012)e+06
# (1.8318+/-0.0006)e+06

# %%
# lco32 = line_luminosity(s_co32_dvs, lum_dists, redshifts, obs_freqs)
# [f'{i:.E}' for i in lco32.value]

# %% [markdown]
# ## WRONG UNITS ^ ??? cant convert??? i think the 3.25e7 has units on it which make it all work out. not specified in the carilli paper.
#
# ## edit: check eqn 3 here. original form: 3.25e7 is actually  c^2/(2k). which has the units. http://adsabs.harvard.edu/full/1992ApJ...398L..29S

# %%
lco10 = lco32 / .27
[f'{i:.3E}' for i in lco10]
# Out:
# ['(4.565+/-0.019)E+06', '(8.541+/-0.005)E+06', '(6.784+/-0.002)E+06']

# %%
a_conversion_factor = 4.6 * u.M_sun / (u.K * u.km * u.pc**2 / u.s)
gas_mass = a_conversion_factor * lco10
[f'{i:.3E}' for i in gas_mass.value]
# Out:
# ['(2.100+/-0.009)E+07', '(3.929+/-0.002)E+07', '(3.121+/-0.001)E+07']

# %%
amplifications = np.array([ufloat(2.86, .04), ufloat(8.1, .4), ufloat(6.1, .1)])
delensed_gas_mass = gas_mass / amplifications # all the calculations scale linearly with the flux
[f'{i:.3E}' for i in delensed_gas_mass.value]
# Out:
# ['(7.342+/-0.107)E+06', '(4.851+/-0.240)E+06', '(5.116+/-0.084)E+06']

# %%
(delensed_gas_mass[2] - delensed_gas_mass[1]) / ((delensed_gas_mass[1] + delensed_gas_mass[2]) / 2)
# Out:
# <Quantity 0.0532678403379318+/-0.05199938445593778>

# %% [markdown]
# ## consistent within 5% of each other

# %%
2.65 / 4.98

# %%
fig = plt.figure(figsize=(7, 15), dpi=100)
for i, j in enumerate(zprofs):
    ax = fig.add_subplot(3, 1, i+1)
    vel_r = velocity_radio(j.freq, co_j32_freq, redshifts[i])
    xlabs_bottom = [i.n-100 for i in vel_r[::6] / 1000] # convert to km/s
    
    ax.step(j.freq, j.intensity)
    ax.set_title(f'Gal. {j.name}, z~{redshifts[i]:.2f}')
    ax2 = ax.twiny()
    ax2.set_xlim(xlabs_bottom[0], xlabs_bottom[-1])
    plt.xticks(xlabs_bottom)
    
    ax2.set_xlim(xlabs_bottom[0], xlabs_bottom[-1])
    plt.xticks((np.arange(xlabs_bottom[-1], xlabs_bottom[0], 100)[::-1] / 100).astype(int) * 100)
    
    ax2.xaxis.set_major_locator(ticker.MultipleLocator(500))
    ax2.xaxis.set_major_formatter(ticker.FormatStrFormatter('%d'))

    # For the minor ticks, use no labels; default NullFormatter.
    ax2.xaxis.set_minor_locator(ticker.MultipleLocator(250))
    
    ax.xaxis.tick_top()
    ax.xaxis.set_label_position('top')
    
    ax2.xaxis.tick_bottom()
    ax2.xaxis.set_label_position('bottom')
    
    ax.set_ylabel('Intensity (Jy/beam)')   
    ax.set_xlabel('Observed frequency (GHz)', labelpad=10)
    ax2.set_xlabel('Radio velocity (km/s)', labelpad=10)
    
    ax.set_ylim(-0.00025, .00065)
    
    ax.axhline(0, linestyle=":", c='black', alpha=0.5)

plt.subplots_adjust(hspace=.6)
plt.tight_layout()
plt.savefig('figs/spectra_vert.pdf', bbox_inches = "tight")

# %%
tab = Table.read('../../surp2020/resources/tab1.tex')
tab.add_index(tab.colnames)

c = (tab[['Galaxy ID']], 
     SkyCoord(ra=tab[['R.A. (J2000)']], dec=tab[['Dec. (J2000)']], unit=('hourangle', 'deg'), frame='icrs'))

hdu160 = fits.open('../../surp2020/resources/HST_images/j0454m0301-f160w_drz_sci.fits')[0]
wcs = WCS(hdu160.header)

xs, ys = c[1].to_pixel(wcs)
xdiff = np.abs(xs.min() - xs.max())
ydiff = np.abs(ys.min() - ys.max())
xmargin = 0.2
ymargin = 0.2
xlims = (xs.min() - xmargin * xdiff, xs.max() + xmargin * xdiff)
ylims = (ys.min() - ymargin * ydiff, ys.max() + ymargin * ydiff)

# %%
fig = plt.figure(figsize=(16, 12))
f1 = aplpy.FITSFigure('../../surp2020/resources/HST_images/j0454m0301-f160w_drz_sci.fits', figure=fig);

plt.xlim(xlims)
plt.ylim(ylims)
plt.xlabel('Right Ascension (J2000)')
plt.ylabel('Declination (J2000)')

f1.show_rgb('../../surp2020/output/new/99.85-99.85-99.00.png')

for i in range(3, 6):
    label, coord = c[0][i][0], c[1][i]
    pixel_region = f1.world2pixel(coord.ra, coord.dec)
    circ = patches.Circle(pixel_region, radius=20, linewidth=1, edgecolor='r', facecolor='none')
    f1.ax.add_patch(circ)
    f1.ax.annotate(label, 
                   xy=pixel_region, c='white', xycoords='data',
                   xytext=(15, 0), textcoords='offset points')
    
plt.savefig('figs/annotated.pdf')

# %%
sfr = ufloat(99, 9)
sfe = sfr / delensed_gas_mass
[f'{i:.2E}' for i in sfe.value]

# %%
plt.step(z2a.freq, z2a.intensity)
plt.axhline(0, linestyle=":")
plt.axhline(maxsig, c='orange')
plt.axhline(RMS(z2a.intensity), c='red')
plt.axvline(g_fits[0].mean.value + up_fwhm/2)
plt.axvline(g_fits[0].mean.value - up_fwhm/2)

# %%
x1

# %%
x2 = x1 / .27
x2

# %%
x3 = x2 * a_conversion_factor
x3

# %%
x4 = x3 / 2.86
x4

# %%
x5 = (99 * u.M_sun / u.yr) / x4
x5
